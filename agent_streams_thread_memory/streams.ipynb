# %%
from langchain.agents import create_agent
from dotenv import load_dotenv

load_dotenv()
def get_weather(city: str) -> str:
    """Get weather for a city."""
    return f"It's always sunny in {city}!"


agent = create_agent(
    model="gpt-5-nano",
    tools=[get_weather],
)

stream = agent.stream_events({
    "messages": [{"role": "user", "content": "What is the weather in SF?"}],
}, version="v3")

for message in stream.messages:
    for delta in message.text:
        print(delta, end="", flush=True)

final_state = stream.output

# %%
from langchain.agents import create_agent
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv

load_dotenv()

def get_weather(city: str) -> str:
    """Get weather for a given city."""
    return f"It's always sunny in {city}!"


weather_agent = create_agent(
    model=init_chat_model("openai:gpt-5.5"),
    tools=[get_weather],
    name="weather_agent",
)


def call_weather(query: str) -> str:
    """Query the weather agent."""
    result = weather_agent.invoke({"messages": [{"role": "user", "content": query}]})
    return result["messages"][-1].text


supervisor = create_agent(
    model=init_chat_model("openai:gpt-5.5"),
    tools=[call_weather],
    name="supervisor",
)

stream = supervisor.stream_events(
    {"messages": [{"role": "user", "content": "What's the weather in Boston?"}]},
    version="v3",
)

for subagent in stream.subagents:
    print(f"{subagent.name}: ", end="")
    for message in subagent.messages:
        for token in message.text:
            print(token, end="", flush=True)
    print()
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[2], line 36
#      32     {"messages": [{"role": "user", "content": "What's the weather in Boston?"}]},
#      33     version="v3",
#      34 )
#      35
# ---> 36 for subagent in stream.subagents:
#      37     print(f"{subagent.name}: ", end="")
#      38     for message in subagent.messages:
#      39         for token in message.text:
#
# File c:\work\tutorial-agentic-ai\.venv\Lib\site-packages\langgraph\stream\stream_channel.py:189, in StreamChannel._sync_cursor(self)
#     187 elif self._closed:
#     188     if self._error is not None:
# --> 189         raise self._error
#     190     return
#     191 elif self._request_more is not None:
#
# File c:\work\tutorial-agentic-ai\.venv\Lib\site-packages\langgraph\stream\run_stream.py:134, in GraphRunStream._pump_next(self)
#     132     return False
#     133 try:
# --> 134     part = next(self._graph_iter)
#     135     event = convert_to_protocol_event(part)
#     136     self._observe_event(event)
#
# File c:\work\tutorial-agentic-ai\.venv\Lib\site-packages\langgraph\pregel\main.py:2967, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    2965 for task in loop.match_cached_writes():
#    2966     loop.output_writes(task.id, task.writes, cached=True)
# -> 2967 for _ in runner.tick(
#    2968     [t for t in loop.tasks.values() if not t.writes],
#    2969     timeout=self.step_timeout,
#    2970     get_waiter=get_waiter,
#    2971     schedule_task=loop.accept_push,
#    2972 ):
#    2973     # emit output
#    2974     yield from _output(
#    2975         stream_mode,
#    2976         print_mode,
#    (...)   2982         _state_mapper,
#    2983     )
#    2984 loop.after_tick()
#
# File c:\work\tutorial-agentic-ai\.venv\Lib\site-packages\langgraph\pregel\_runner.py:344, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     342 # panic on failure or timeout
#     343 try:
# --> 344     _panic_or_proceed(
#     345         futures.done.union(f for f, t in futures.items() if t is not None),
#     346         panic=reraise,
#     347         handled_exception_ids=self._handled_exception_ids,
#     348         handled_futures=handled_futures,
#     349     )
#     350 except Exception as exc:
#     351     if tb := exc.__traceback__:
#
# File c:\work\tutorial-agentic-ai\.venv\Lib\site-packages\langgraph\pregel\_runner.py:687, in _panic_or_proceed(futs, timeout_exc_cls, panic, handled_exception_ids, handled_futures)
#     685                 interrupts.append(exc)
#     686             elif fut not in SKIP_RERAISE_SET:
# --> 687                 raise exc
#     688 # raise combined interrupts
#     689 if interrupts:
#
# File c:\work\tutorial-agentic-ai\.venv\Lib\site-packages\langgraph\pregel\_executor.py:80, in BackgroundExecutor.done(self, task)
#      78 """Remove the task from the tasks dict when it's done."""
#      79 try:
# ---> 80     task.result()
#      81 except GraphBubbleUp:
#      82     # This exception is an interruption signal, not an error
#      83     # so we don't want to re-raise it on exit
#      84     self.tasks.pop(task)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File c:\work\tutorial-agentic-ai\.venv\Lib\site-packages\langgraph\pregel\_retry.py:617, in run_with_retry(task, retry_policy, configurable)
#     615     task.writes.clear()
#     616     # run the task
# --> 617     return task.proc.invoke(task.input, config)
#     618 except ParentCommand as exc:
#     619     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File c:\work\tutorial-agentic-ai\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:684, in RunnableSeq.invoke(self, input, config, **kwargs)
#     682     # run in context
#     683     with set_config_context(config, run) as context:
# --> 684         input = context.run(step.invoke, input, config, **kwargs)
#     685 else:
#     686     input = step.invoke(input, config)
#
# File c:\work\tutorial-agentic-ai\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:426, in RunnableCallable.invoke(self, input, config, **kwargs)
#     424         run_manager.on_chain_end(ret)
#     425 else:
# --> 426     ret = self.func(*args, **kwargs)
#     427 if self.recurse and isinstance(ret, Runnable):
#     428     return ret.invoke(input, config)
#
# File c:\work\tutorial-agentic-ai\.venv\Lib\site-packages\langchain\agents\factory.py:1447, in create_agent.<locals>.model_node(state, runtime)
#    1435 request = ModelRequest(
#    1436     model=model,
#    1437     tools=default_tools,
#    (...)   1443     runtime=runtime,
#    1444 )
#    1446 if wrap_model_call_handler is None:
# -> 1447     model_response = _execute_model_sync(request)
#    1448     return _build_commands(model_response)
#    1450 result = wrap_model_call_handler(request, _execute_model_sync)
#
# File c:\work\tutorial-agentic-ai\.venv\Lib\site-packages\langchain\agents\factory.py:1419, in create_agent.<locals>._execute_model_sync(request)
#    1416 if request.system_message:
#    1417     messages = [request.system_message, *messages]
# -> 1419 output = model_.invoke(messages)
#    1420 if name:
#    1421     output.name = name
#
# File c:\work\tutorial-agentic-ai\.venv\Lib\site-packages\langchain_core\runnables\base.py:6002, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5995 @override
#    5996 def invoke(
#    5997     self,
#    (...)   6000     **kwargs: Any | None,
#    6001 ) -> Output:
# -> 6002     return self.bound.invoke(
#    6003         input,
#    6004         self._merge_configs(config),
#    6005         **{**self.kwargs, **kwargs},
#    6006     )
#
# File c:\work\tutorial-agentic-ai\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File c:\work\tutorial-agentic-ai\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\work\tutorial-agentic-ai\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File c:\work\tutorial-agentic-ai\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1925, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1919 stream_accum = ChatModelStream(
#    1920     message_id=(
#    1921         f"{LC_ID_PREFIX}-{run_manager.run_id}" if run_manager else None
#    1922     )
#    1923 )
#    1924 assert run_manager is not None  # noqa: S101
# -> 1925 for _event in self._iter_v2_events(
#    1926     messages,
#    1927     run_manager=run_manager,
#    1928     stream=stream_accum,
#    1929     stop=stop,
#    1930     **kwargs,
#    1931 ):
#    1932     pass
#    1933 if stream_accum.output_message is None:
#
# File c:\work\tutorial-agentic-ai\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:678, in BaseChatModel._iter_v2_events(self, messages, run_manager, stream, stop, **kwargs)
#     673 else:
#     674     event_iter = chunks_to_events(
#     675         self._stream(messages, stop=stop, run_manager=run_manager, **kwargs),
#     676         message_id=stream.message_id,
#     677     )
# --> 678 for event in event_iter:
#     679     stream.dispatch(event)
#     680     run_manager.on_stream_event(event)
#
# File c:\work\tutorial-agentic-ai\.venv\Lib\site-packages\langchain_core\language_models\_compat_bridge.py:618, in chunks_to_events(chunks, message_id)
#     615 response_metadata: dict[str, Any] = {}
#     616 additional_kwargs: dict[str, Any] = {}
# --> 618 for chunk in chunks:
#     619     msg = chunk.message
#     620     if not isinstance(msg, AIMessageChunk):
#
# File c:\work\tutorial-agentic-ai\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1697, in BaseChatOpenAI._stream(self, messages, stop, run_manager, stream_usage, **kwargs)
#    1695     _handle_openai_bad_request(e)
#    1696 except openai.APIError as e:
# -> 1697     _handle_openai_api_error(e)
#    1698 if hasattr(response, "get_final_completion") and "response_format" in payload:
#    1699     final_completion = response.get_final_completion()
#
# File c:\work\tutorial-agentic-ai\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1670, in BaseChatOpenAI._stream(self, messages, stop, run_manager, stream_usage, **kwargs)
#    1668         base_generation_info = {"headers": dict(raw_response.headers)}
#    1669     else:
# -> 1670         response = self.client.create(**payload)
#    1671     context_manager = response
#    1672 with context_manager as response:
#
# File c:\work\tutorial-agentic-ai\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File c:\work\tutorial-agentic-ai\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1296, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1247 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1248 def create(
#    1249     self,
#    (...)   1293     timeout: float | httpx2.Timeout | None | NotGiven = not_given,
#    1294 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1295     validate_response_format(response_format)
# -> 1296     return self._post(
#    1297         "/chat/completions",
#    1298         body=maybe_transform(
#    1299             {
#    1300                 "messages": messages,
#    1301                 "model": model,
#    1302                 "audio": audio,
#    1303                 "frequency_penalty": frequency_penalty,
#    1304                 "function_call": function_call,
#    1305                 "functions": functions,
#    1306                 "logit_bias": logit_bias,
#    1307                 "logprobs": logprobs,
#    1308                 "max_completion_tokens": max_completion_tokens,
#    1309                 "max_tokens": max_tokens,
#    1310                 "metadata": metadata,
#    1311                 "modalities": modalities,
#    1312                 "moderation": moderation,
#    1313                 "n": n,
#    1314                 "parallel_tool_calls": parallel_tool_calls,
#    1315                 "prediction": prediction,
#    1316                 "presence_penalty": presence_penalty,
#    1317                 "prompt_cache_key": prompt_cache_key,
#    1318                 "prompt_cache_options": prompt_cache_options,
#    1319                 "prompt_cache_retention": prompt_cache_retention,
#    1320                 "reasoning_effort": reasoning_effort,
#    1321                 "response_format": response_format,
#    1322                 "safety_identifier": safety_identifier,
#    1323                 "seed": seed,
#    1324                 "service_tier": service_tier,
#    1325                 "stop": stop,
#    1326                 "store": store,
#    1327                 "stream": stream,
#    1328                 "stream_options": stream_options,
#    1329                 "temperature": temperature,
#    1330                 "tool_choice": tool_choice,
#    1331                 "tools": tools,
#    1332                 "top_logprobs": top_logprobs,
#    1333                 "top_p": top_p,
#    1334                 "user": user,
#    1335                 "verbosity": verbosity,
#    1336                 "web_search_options": web_search_options,
#    1337             },
#    1338             completion_create_params.CompletionCreateParamsStreaming
#    1339             if stream
#    1340             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1341         ),
#    1342         options=make_request_options(
#    1343             extra_headers=extra_headers,
#    1344             extra_query=extra_query,
#    1345             extra_body=extra_body,
#    1346             timeout=timeout,
#    1347             security={"bearer_auth": True},
#    1348         ),
#    1349         cast_to=ChatCompletion,
#    1350         stream=stream or False,
#    1351         stream_cls=Stream[ChatCompletionChunk],
#    1352     )
#
# File c:\work\tutorial-agentic-ai\.venv\Lib\site-packages\openai\_base_client.py:1382, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1373     warnings.warn(
#    1374         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1375         "Please pass raw bytes via the `content` parameter instead.",
#    1376         DeprecationWarning,
#    1377         stacklevel=2,
#    1378     )
#    1379 opts = FinalRequestOptions.construct(
#    1380     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1381 )
# -> 1382 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\work\tutorial-agentic-ai\.venv\Lib\site-packages\openai\_base_client.py:1155, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1152             err.response.read()
#    1154         log.debug("Re-raising status error")
# -> 1155         raise self._make_status_error_from_response(err.response) from None
#    1157     break
#    1159 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-proj-********************************************************************************************************************************************************lPcA. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'code': 'invalid_api_key', 'param': None}, 'status': 401}
# During task with name 'model' and id 'e690e990-48d5-ec10-a0b0-5a9700f79c58'
